# %% [markdown]
# # Slider (Öncesi Sonrası)
# Orman yangını, deprem vs gibi felaketlerde kullanılan öncesi sonrası kaydırma uygulaması.

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9076-928B
#
#  Directory of C:\Users\cotak_8sfhz1n\BtkAkademiAntalya\Day4
#
# 04.11.2024  13:01    <DIR>          .
# 03.11.2024  10:09    <DIR>          ..
# 03.11.2024  14:47    <DIR>          .gradio
# 03.11.2024  15:29    <DIR>          .ipynb_checkpoints
# 04.11.2024  12:46         5.648.112 Auto(EDA).ipynb
# 03.11.2024  12:47             6.779 BingImageDownloader.ipynb
# 03.11.2024  14:34    <DIR>          cat
# 03.11.2024  10:40    <DIR>          deprem
# 03.11.2024  12:20               610 dunya.zenginleri.csv
# 04.11.2024  12:56               610 dunya_zenginleri.csv
# 04.11.2024  12:56             5.622 dunya_zenginleri.xlsx
# 04.11.2024  12:52            12.381 Gradio-Bing-GörselAramaYuzu.ipynb
# 03.11.2024  11:13           291.757 index.html
# 03.11.2024  14:36    <DIR>          köpek
# 03.11.2024  10:40    <DIR>          orman
# 04.11.2024  12:56            22.231 PandasIleVeriAlma.ipynb
# ...

# %%
pip install leafmap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import leafmap.foliumap as leafmap

# %%
img1=r'C:\Users\cotak_8sfhz1n\BtkAkademiAntalya\Day4\orman\sonra.jpg'
img2=r'C:\Users\cotak_8sfhz1n\BtkAkademiAntalya\Day4\orman\once.jpg'

# %%
leafmap.image_comparison(img1,img2,
                         label1='Sonra',label2='Once',
                         starting_position=50,out_html="slide_orman.html")
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 495; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Sonra',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Once',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
#         </head>
# ...

# %%
img1=r"C:\Users\cotak_8sfhz1n\BtkAkademiAntalya\Day4\resim\656730077 (1).jpg"
img2=r"C:\Users\cotak_8sfhz1n\BtkAkademiAntalya\Day4\resim\656730077.jpg"

# %%
leafmap.image_comparison(img1,img2,
                         label1='Sonra',label2='Once',
                         starting_position=50,out_html="degisim.html")
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 854; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Sonra',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Once',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
#         </head>
# ...
